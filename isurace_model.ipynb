# %% [markdown]
# <a href="https://colab.research.google.com/github/shahyash07/Insurance-prediction-project-/blob/master/isurace_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret

# %%
# importing libraries
import numpy as np
import pandas as pd
import sklearn as sk

import warnings  # ignoring the warnings
warnings.filterwarnings('ignore')

# %%
from pycaret.regression import *

# %%
# importing data set from drive
from google.colab import drive
drive.mount('/content/gdrive')

input_path = '/content/gdrive/My Drive/'
# reading the data (target)
target_dataset = pd.read_csv(input_path + 'insurance.csv')

insurance = target_dataset.copy()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
r1 = setup(insurance, target = 'charges', session_id = 123,
           normalize = True,
           polynomial_features = True, trigonometry_features = True,
           feature_interaction=True, 
           bin_numeric_features= ['age', 'bmi'])
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_b84aa9aa_ace2_11ea_a67d_0242ac1c0002row15_col1 {
#             background-color:  lightgreen;
#         }    #T_b84aa9aa_ace2_11ea_a67d_0242ac1c0002row25_col1 {
#             background-color:  lightgreen;
#         }    #T_b84aa9aa_ace2_11ea_a67d_0242ac1c0002row32_col1 {
#             background-color:  lightgreen;
#         }    #T_b84aa9aa_ace2_11ea_a67d_0242ac1c0002row34_col1 {
#             background-color:  lightgreen;
#         }    #T_b84aa9aa_ace2_11ea_a67d_0242ac1c0002row39_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_b84aa9aa_ace2_11ea_a67d_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
lr = compare_models()

# %%
# Train a linear regression model

lr= create_model('lr')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# 0     2983.2472  2.094223e+07  4576.2681  0.8749  0.4151  0.3455
# 1     3690.3896  3.454394e+07  5877.4091  0.7991  0.4532  0.3556
# 2     3041.5305  2.421707e+07  4921.0843  0.6934  0.5344  0.3848
# 3     3263.7057  2.759336e+07  5252.9385  0.7696  0.5607  0.4825
# 4     3383.6295  2.922825e+07  5406.3161  0.7826  0.4781  0.3269
# 5     3231.4401  2.488083e+07  4988.0688  0.8399  0.3973  0.2877
# 6     2924.5603  2.463091e+07  4962.9536  0.8324  0.3836  0.3153
# 7     3492.6257  3.090267e+07  5559.0174  0.8301  0.4778  0.3047
# 8     3152.2860  2.269010e+07  4763.4122  0.8534  0.4023  0.3420
# 9     3301.6036  2.932424e+07  5415.1857  0.8111  0.5233  0.3737
# Mean  3246.5018  2.689536e+07  5172.2654  0.8087  0.4626  0.3519
# SD     224.4583  3.948059e+06   378.1942  0.0490  0.0595  0.0520

# %%
# save transformation pipeline and model 
save_model(lr, model_name = 'deployment_28042020')
# Out:
# Transformation Pipeline and Model Succesfully Saved
